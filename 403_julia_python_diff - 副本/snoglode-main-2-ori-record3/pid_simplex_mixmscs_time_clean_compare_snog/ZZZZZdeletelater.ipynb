# %%
a=0.9669763739971017
b=0.9669763506929365
print(b-a)
# Out:
# -2.3304165153170686e-08

# %%
--- [Iter 0] ---
  [ipopt ] ok=True, status=ok, term=optimal, time=0.122s, ef_obj=0.9669763739716941, true_obj(per-scen)=0.966976412, gurobi_LB(per-scen)=-inf
  [gurobi] ok=True, status=ok, term=optimal, time=33.437s, ef_obj=0.9669763178936428, true_obj(per-scen)=0.966976401, gurobi_LB(per-scen)=0.322325439
  [winner] gurobi, ub_updated=True, UB_incumbent=0.966976401, LB_global_end=0.966787556, UB_global_end=0.966976401

--- [Iter 1] ---
  [ipopt ] ok=True, status=ok, term=optimal, time=0.113s, ef_obj=0.9669763739971017, true_obj(per-scen)=0.966976412, gurobi_LB(per-scen)=-inf
  [gurobi] ok=True, status=ok, term=optimal, time=17.595s, ef_obj=0.9669763506929365, true_obj(per-scen)=0.966976360, gurobi_LB(per-scen)=0.322325439
  [winner] gurobi, ub_updated=True, UB_incumbent=0.966976360, LB_global_end=0.966787549, UB_global_end=0.966976360

# %%
  [ipopt ] ok=True, status=ok, term=optimal, time=0.119s, ef_obj=0.9669763739716941, true_obj(per-scen)=0.966976412
  [gurobi] ok=True, status=ok, term=optimal, time=32.743s, ef_obj=0.9669763178936428, true_obj(per-scen)=0.966976401


  --- [Iter 1] ---
  [ipopt ] ok=True, status=ok, term=optimal, time=0.098s, ef_obj=0.9669763739971017, true_obj(per-scen)=0.966976412
  [gurobi] ok=True, status=ok, term=optimal, time=15.982s, ef_obj=0.9669763506929365, true_obj(per-scen)=0.966976360
  [winner] gurobi, ub_updated=True, UB_incumbent=0.966976360, LB_global_end=0.966787549, UB_global_end=0.966976360

--- [Iter 2] ---
  [ipopt ] ok=True, status=ok, term=optimal, time=0.106s, ef_obj=0.9669763740011253, true_obj(per-scen)=0.966976413
  [gurobi] ok=True, status=ok, term=optimal, time=18.798s, ef_obj=0.9669762371169013, true_obj(per-scen)=0.966976397
  [winner] gurobi, ub_updated=False, UB_incumbent=0.966976360, LB_global_end=0.966787554, UB_global_end=0.966976360

--- [Iter 3] ---
  [ipopt ] ok=True, status=ok, term=optimal, time=0.096s, ef_obj=0.9669763718039833, true_obj(per-scen)=0.966976410
  [gurobi] ok=True, status=ok, term=optimal, time=5.522s, ef_obj=0.9669763466821907, true_obj(per-scen)=0.966976363
  [winner] gurobi, ub_updated=False, UB_incumbent=0.966976360, LB_global_end=0.966787552, UB_global_end=0.966976360
  what is the difference between ef_obj, true_obj(per-scen) and gurobi_LB(per-scen)
