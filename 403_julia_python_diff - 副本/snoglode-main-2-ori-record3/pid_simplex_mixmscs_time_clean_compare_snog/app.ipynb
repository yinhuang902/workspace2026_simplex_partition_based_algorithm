# %%
from time import perf_counter  

from modeling import build_models_from_csv
from bundles import BaseBundle, MSBundle
from utils import (
    tighten_bounds_one_model,
    MIN_DIST, ACTIVE_TOL, GAP_STOP_TOL,
)
from simplex_specialstart import run_pid_simplex_3d

# setup scenario number and target_nodesk
csv_path       = "data.csv"
max_scenarios  = 5
target_nodes   = 1000

bounds={
    "Kp": (-10.0, 10.0),
    "Ki": (-100.0, 100.0),
    "Kd": (-100.0, 100.0),
    "x": (-2.5, 2.5),
    "u": (-5.0, 5.0),
    "e": (None, None),
    "I": (None, None),
}

weights = (10.0, 0.01)


# ====== stage 1：load data and generate models ======
T   = 15.0          
nfe = 20            

t_load0 = perf_counter()
model_list, first_stg_vars_list, m_tmpl_list, nfe = build_models_from_csv(
    csv_path=csv_path,
    T=T,
    nfe=nfe,
    weights=weights,
    bounds=bounds,
    sp0=0.0,
    sp1=0.5,
    tau_xs_col="tau_xs",
    tau_us_col="tau_us",
    tau_ds_col="tau_ds",          
    disturb_prefix="disturbance_",
    setpoint_change_col="setpoint_change",
    max_scenarios=max_scenarios,
    skip=0,
)
t_load1 = perf_counter()
print(f"[Time] Data load & scenario build: {t_load1 - t_load0:.3f}s")


# ====== stage 1.5：FBBT / OBBT ======
# same as snog: FBBT open,OBBT open
obbt_solver_opts = {
    "NonConvex": 2,
    "MIPGap": 1,     
    "TimeLimit": 15   
}
for m, yvars in zip(model_list, first_stg_vars_list):
    tighten_bounds_one_model(m, yvars,
                             use_fbbt=False,
                             use_obbt=False,
                             obbt_solver_name="gurobi",
                             obbt_solver_opts=obbt_solver_opts,
                             max_rounds=3, tol=1e-6, verbose=True)

# ====== stage 2: Persistent Solver Packaging ======
ub_options = {
    'NonConvex': 2,      
}
lb_options = {
    'NonConvex': 2,
    'MIPGap': 1e-1,            
    'TimeLimit': 60 
}

t_wrap0 = perf_counter()
base_bundles = [BaseBundle(m, ub_options) for m in model_list]  
ms_bundles   = [MSBundle(m, yvars, lb_options) for m, yvars in zip(model_list, first_stg_vars_list)]  
t_wrap1 = perf_counter()
print(f"[Time] Persistent wrapper (GurobiPersistent) setup: {t_wrap1 - t_wrap0:.3f}s")

# ====== stage 3：main loop ======
agg_bundle = None  

t_run0 = perf_counter()
hist = run_pid_simplex_3d(
    base_bundles=base_bundles,
    ms_bundles=ms_bundles,
    model_list=model_list,
    first_vars_list=first_stg_vars_list,
    target_nodes=target_nodes,
    min_dist=0,
    active_tol=ACTIVE_TOL,
    verbose=True,
    agg_bundle=agg_bundle,
    gap_stop_tol=1e-6,
    use_exact_opt=False,
    exact_solver_name="gurobi",
    exact_solver_opts={"NonConvex": 2, "TimeLimit": 60},
    time_limit=60*60*7,
    enable_3d_plot=False,   
    plot_every=None,        
)
t_run1 = perf_counter()
print(f"[Time] Main loop total: {t_run1 - t_run0:.3f}s")

# ====== print output ======
print("\n==== Done ====")
print(f"Total nodes: {len(hist['nodes'])}")
print(f"Best UB: {min(hist['UB_hist']) if hist['UB_hist'] else None}")
print(f"Last LB: {hist['LB_hist'][-1] if hist['LB_hist'] else None}")
# Out:
# [Time] Data load & scenario build: 0.022s
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# [Tighten] rounds=1, changed=False
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2689754
# Academic license 2689754 - for non-commercial use only - registered to yi___@math.ubc.ca
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# Set parameter MIPGap to value 0.1
# Set parameter NumericFocus to value 1
# Set parameter Presolve to value 2
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 60
# [Time] Persistent wrapper (GurobiPersistent) setup: 1.388s
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(-10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, -100.0, 100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [BaseBundle.eval_at] Infeasible/Error for K=(10.0, 100.0, -100.0): status=error, term=error
# [TIMING] Pre-loop vertex Q evals: 0.48s  (8 nodes x 5 scenarios = 40 solves)
# [EF-UB] Initialized ipopt EF with 5 scenarios, time_ub=60.0s
#
# ======================================================================
# [TIMING] === Pre-loop phase summary ===
#   corners_and_mesh               :       0.00s
#   vertex_Q_evals                 :       0.48s
#   exact_optima                   :       0.00s
#   ef_init                        :       0.03s
#   TOTAL                          :       0.51s
# ======================================================================
#
# [Iter 0] MIPGap overridden to 0.1 (original: 0.1)
# Discarded solution information
# [Invariant] MS scen None: dual=-5.500707e+09 > primal=-5.500707e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.481254e+09 > primal=-5.481254e+09
# Discarded solution information
# Discarded solution information
# [Invariant] MS scen None: dual=-5.194287e+09 > primal=-5.194287e+09
# [Invariant] MS scen None: dual=-5.806922e+09 > primal=-5.806922e+09
# [Invariant] MS scen None: dual=-5.817119e+09 > primal=-5.817119e+09
# [Invariant] MS scen None: dual=-5.596691e+09 > primal=-5.596691e+09
# [Invariant] MS scen None: dual=-5.719282e+09 > primal=-5.719282e+09
# [Invariant] MS scen None: dual=-5.735561e+09 > primal=-5.735561e+09
# [Invariant] MS scen None: dual=-5.718800e+09 > primal=-5.718800e+09
# [Invariant] MS scen None: dual=-5.724298e+09 > primal=-5.724298e+09
# [Bundle] MS scen None: infeasibleOrUnbounded. ms_val=nan.
# [Bundle] MS scen None: not optimal. Status=warning, Term=infeasibleOrUnbounded.
# [Invariant] MS scen None: dual=-5.870800e+09 > primal=-5.870800e+09
# [Iter 0] MIPGap restored to 0.1
# [Iter 0] #simplices = 6, #active = 6, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 0] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            9.955344e-01      4.065069e+09     -2.967466e+10      4.977672e+00     [1.12e+01, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
# T2            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T3            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T4            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T5            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
#
# == [Iter 0] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
#   (none)
# [Iter 0] created=6 (cum=6), active=6, active+UB=2, ms_recomputed=6
# [Iter 0] EF-ipopt: ok=True, ef_obj=0.9841670257415726, true_obj=9.841670e-01, time=0.095s
# [Iter 0] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999891529588373, -99.99979183385918, 0.8142777652971412)
# [Iter 0] Pre-split gap: -5.683677e-02 (-1.155%)
# [Iter 0] Active simplex ratio = 1.000000
# [Iter 0] UB point (-9.999891529588373, -99.99979183385918, 0.8142777652971412) is geometrically in simplices [1]
#   T1 verts=[3, 1, 4, 0]: λ=[0.000001, 0.504070, 0.000005, 0.495923], LB=4.977672007, c_s=[0.9960029127022256, 1.0001366770450069, 0.9579954878938712, 1.0551989733060005, 0.9683379558464811]
#
# == [Iter 0] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T1 ---
#     scen 0: status=optimal, dual=0.996002913, primal=0.996002913  ✓ dual ≤ primal (gap=1.110223e-16)
#              cs_primal_K=(-9.999216646683243, -99.99852406033013, 0.9388331317148486)
#              indep_Q(cs_K)=0.996002918  → dual ≤ indep_Q (consistent, diff=4.973934e-09)
#     scen 1: status=optimal, dual=1.000136677, primal=1.000136677  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.999983393339464, -0.15781395634996587, 0.00040036514586223133)
#              indep_Q(cs_K)=1.000136678  → dual ≤ indep_Q (consistent, diff=1.132161e-09)
#     scen 2: status=optimal, dual=0.957995488, primal=0.957995488  ✓ dual ≤ primal (gap=-2.220446e-16)
#              cs_primal_K=(-9.998442794608906, -99.99686925671598, -2.736029187431506e-10)
#              indep_Q(cs_K)=0.957995515  → dual ≤ indep_Q (consistent, diff=2.714000e-08)
#     scen 3: status=optimal, dual=1.055198973, primal=1.055198973  ✓ dual ≤ primal (gap=2.220446e-16)
#              cs_primal_K=(-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#              indep_Q(cs_K)=1.055198979  → dual ≤ indep_Q (consistent, diff=5.506025e-09)
#     scen 4: status=optimal, dual=0.968337956, primal=0.968337956  ✓ dual ≤ primal (gap=0.000000e+00)
#              cs_primal_K=(-9.998518091599312, -99.9972050307925, 0.39376151703840556)
#              indep_Q(cs_K)=0.968337957  → dual ≤ indep_Q (consistent, diff=1.643293e-09)
#   sum(c_s_dual)=4.977672007, UB_total=24.604176169, UB_per_scen=4.920835234
#
#   == Per-scenario Q_s at K_EF = (-9.999891529588373, -99.99979183385918, 0.8142777652971412) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=0.996002913  ✓ Q_s(K_EF) > c_s_dual (diff=1.232267e-05)
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=1.000136677  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 2: Q_s(K_EF)=0.956484730, c_s_dual=0.957995488  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 3: Q_s(K_EF)=1.054727427, c_s_dual=1.055198973  ⚠ Q_s(K_EF) < c_s_dual → GUROBI CS DUAL IS WRONG
#     scen 4: Q_s(K_EF)=0.968481558, c_s_dual=0.968337956  ✓ Q_s(K_EF) > c_s_dual (diff=1.436021e-04)
#     SUM Q_s(K_EF)=4.920835234, sum(c_s)=4.977672007, diff=-5.683677e-02
#
# [Iter 0] LB = 4.977672 = UB(4.920835) + ms_b(-2.967e+10) from T1
# [Iter 0] Scene 0: Switched to c_s point. dist_ms_c=1.71e+01 < 1000.0, dist_c_verts=9.91e+01 > 1e-06
# [Iter 0] Scene 1: Switched to c_s point. dist_ms_c=1.01e+02 < 1000.0, dist_c_verts=1.41e+02 > 1e-06
# [Iter 0] Scene 2: Switched to c_s point. dist_ms_c=2.05e+01 < 1000.0, dist_c_verts=1.00e+02 > 1e-06
# [Iter 0] Scene 3: Switched to c_s point. dist_ms_c=2.06e+01 < 1000.0, dist_c_verts=9.97e+01 > 1e-06
# [Iter 0] Scene 4: Switched to c_s point. dist_ms_c=1.92e+01 < 1000.0, dist_c_verts=9.96e+01 > 1e-06
# Chosen node (-9.233467561678685, -98.4408518452537, 0.32994040845543465) with ms=-6.045e+09 (simp T1, scene 3, rank #1, source=c_s)
# [Iter 0] LB simplex = T1, next node simplex = T1, scene 3
# [Selected Simp Info] Iter 0 | Simplex T1 Vertices:
#   v0: (-10.0, 100.0, 100.0)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
# [Iter 0] candidate rank #1: T1, scene=3, ms=-6.045e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T1       3  -6.0448e+09     9.97e+01    (-9.2335, -98.4409, 0.3299)
#    2     T1       2  -6.0269e+09     1.00e+02   (-9.9984, -99.9969, -0.0000)
#    3     T1       4  -5.9790e+09     9.96e+01    (-9.9985, -99.9972, 0.3938)
#    4     T1       1  -5.8171e+09     1.41e+02    (-10.0000, -0.1578, 0.0004)
#    5     T1       0  -5.8069e+09     9.91e+01    (-9.9992, -99.9985, 0.9388)
#
# [Iter 0] per_tet=6, active after q_cut=6, tri_is_None=False
# [Iter 0] bad-quality active simplices (q < 0): 0
# [Iter 0] evaluating Q for scenario 0
# [Iter 0] evaluating Q for scenario 1
# [Iter 0] evaluating Q for scenario 2
# [Iter 0] evaluating Q for scenario 3
# [Iter 0] evaluating Q for scenario 4
#
# [Iter 0] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T1        3       c_s     4.9385e+09     -6.0448e+09    -1.1063e+09    1.0552e+00     (-9.2335, -98.4409, 0.3299)
#
# [Iter 0] subdivision type = interior (code=1) on simplex T1
# [Iter 0] Elapsed: 23.178s
# [Invariant] MS scen None: dual=-6.034060e+09 > primal=-6.034060e+09
# [Invariant] MS scen None: dual=-5.838964e+09 > primal=-5.838964e+09
# [Invariant] MS scen None: dual=-5.688783e+09 > primal=-5.688783e+09
# ======================================================================
# [Iter 0] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 3, 4)
#   Parent LB: 0.995534401 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167047, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.333333e+05
#   Children (4):
#     T5 (0, 1, 4, 8): LB = 0.984142511
#     T6 (0, 3, 4, 8): LB = 0.993970895
#     T7 (0, 1, 3, 8): LB = 0.989997739
#     T8 (1, 3, 4, 8): LB = 0.988355350
#   New global LB: 0.984142511 (from T5 (0, 1, 4, 8))
#   Location: INSIDE
#   Avg CS point Q-value: 0.986724037 (per-scen), point=(np.float64(-9.845925697581922), np.float64(-79.71825282988846), np.float64(0.3325870844161896))
#   Current UB: 0.984167047 (per-scen)
#   UB point: (-9.999891529588373, -99.99979183385918, 0.8142777652971412)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 3, 4)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.095s, ef_obj=0.9841670257415726, true_obj(per-scen)=0.984167047
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-1.8791755128385712, -99.54188147604654, 16.90885917695564): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 0 phase breakdown (total 333.34s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :      22.93s  (  6.9%)  ###
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.20s  (  0.1%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.0%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :     310.17s  ( 93.0%)  ##############################################
#   TOTAL                          :     333.34s
#   #simplices=6, #scenarios=5, total_ms_pairs=30
#   fresh ms solves=30, cache hits=0
# ======================================================================
#
# [Iter 1] #simplices = 9, #active = 1, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 1] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T5            9.841425e-01      4.052430e+09     -2.973785e+10      4.920713e+00     [4.92e+00, 5.00e+10]    [-2.97e+10, 2.03e+10]     1
#
# == [Iter 1] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T6            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T7            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T8            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
#
# [Iter 1] created=9 (cum=19), active=1, active+UB=1, ms_recomputed=0
# [Iter 1] EF-ipopt: ok=True, ef_obj=0.9841670252034649, true_obj=9.841670e-01, time=0.094s
# [Iter 1] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999868030330868, -99.99984336392554, 0.8142777531756429)
# [Iter 1] Pre-split gap: 1.226749e-04 (0.002%)
# [Iter 1] Active simplex ratio = 0.001299
# [Iter 1] UB point (-9.999868030330868, -99.99984336392554, 0.8142777531756429) is geometrically in simplices [5]
#   T5 verts=[8, 1, 4, 0]: λ=[0.000100, 0.504021, 0.000003, 0.495876], LB=4.920712556, c_s=[0.9963144626552408, 0.9453044589370339, 0.9562026556495147, 1.0545523557729262, 0.9683386232895149]
#
# == [Iter 1] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T5 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3110522141071898)
#              indep_Q(cs_K)=0.996314478
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.2486292792626856, -100.0, 0.9401926087665203)
#              indep_Q(cs_K)=0.945304459
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-2.1268867742476636, -100.0, 1.592836476289224)
#              indep_Q(cs_K)=0.956202656
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#              indep_Q(cs_K)=1.054552377
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.3583027097996958)
#              indep_Q(cs_K)=0.968338630
#   sum(c_s_dual)=0.000000000, UB_total=24.604176156, UB_per_scen=4.920835231
#
#   == Per-scenario Q_s at K_EF = (-9.999868030330868, -99.99984336392554, 0.8142777531756429) ==
#     scen 0: Q_s(K_EF)=0.996015235, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727425, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481557, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835231, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 1] LB = 4.920713 = UB(4.920835) + ms_b(-2.974e+10) from T5
# [Iter 1] Scene 0: Switched to c_s point. dist_ms_c=1.93e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 1: Switched to c_s point. dist_ms_c=1.87e+01 < 1000.0, dist_c_verts=7.18e+00 > 1e-06
# [Iter 1] Scene 2: Switched to c_s point. dist_ms_c=1.63e+01 < 1000.0, dist_c_verts=7.38e+00 > 1e-06
# [Iter 1] Scene 3: Switched to c_s point. dist_ms_c=2.03e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# [Iter 1] Scene 4: Switched to c_s point. dist_ms_c=1.82e+01 < 1000.0, dist_c_verts=1.74e+00 > 1e-06
# Chosen node (-9.999024438505662, -99.99948567065238, 0.3476235438684009) with ms=-6.034e+09 (simp T5, scene 3, rank #1, source=c_s)
# [Iter 1] LB simplex = T5, next node simplex = T5, scene 3
# [Selected Simp Info] Iter 1 | Simplex T5 Vertices:
#   v0: (-9.233467561678685, -98.4408518452537, 0.32994040845543465)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
# [Iter 1] candidate rank #1: T5, scene=3, ms=-6.034e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T5       3  -6.0341e+09     1.74e+00    (-9.9990, -99.9995, 0.3476)
#    2     T5       0  -5.9800e+09     1.74e+00  (-10.0000, -100.0000, 0.3111)
#    3     T5       4  -5.9290e+09     1.74e+00  (-10.0000, -100.0000, 0.3583)
#    4     T5       1  -5.9019e+09     7.18e+00   (-2.2486, -100.0000, 0.9402)
#    5     T5       2  -5.8929e+09     7.38e+00   (-2.1269, -100.0000, 1.5928)
#
# [Iter 1] per_tet=9, active after q_cut=1, tri_is_None=False
# [Iter 1] bad-quality active simplices (q < 0): 0
# [Iter 1] evaluating Q for scenario 0
# [Iter 1] evaluating Q for scenario 1
# [Iter 1] evaluating Q for scenario 2
# [Iter 1] evaluating Q for scenario 3
# [Iter 1] evaluating Q for scenario 4
#
# [Iter 1] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T5        3       c_s     5.0157e+09     -6.0341e+09    -1.0183e+09    1.0546e+00     (-9.9990, -99.9995, 0.3476)
#
# [Iter 1] subdivision type = interior (code=1) on simplex T5
# [Iter 1] Elapsed: 0.254s
# [Invariant] MS scen None: dual=-5.880953e+09 > primal=-5.880953e+09
# [Invariant] MS scen None: dual=-5.961202e+09 > primal=-5.961202e+09
# [Invariant] MS scen None: dual=-5.586644e+09 > primal=-5.586644e+09
# ======================================================================
# [Iter 1] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 8)
#   Parent LB: 0.984142511 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167046, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.039432e+03
#   Children (4):
#     T8 (0, 1, 4, 9): LB = 0.984088179
#     T9 (0, 4, 8, 9): LB = 0.984339100
#     T10 (0, 1, 8, 9): LB = 0.984105676
#     T11 (1, 4, 8, 9): LB = 0.984136484
#   New global LB: 0.984088179 (from T8 (0, 1, 4, 9))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984722324 (per-scen), point=(np.float64(-6.874908098403202), np.float64(-99.99989713413046), np.float64(0.7100015105662061))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999868030330868, -99.99984336392554, 0.8142777531756429)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 4, 8)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.094s, ef_obj=0.9841670252034649, true_obj(per-scen)=0.984167046
# ======================================================================
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.914087045729653, -100.0, 18.364665736693418): status=warning, term=infeasibleOrUnbounded
# [BaseBundle.eval_at] Infeasible/Error for K=(-4.914087045729653, -100.0, 18.364665736693418): status=warning, term=infeasibleOrUnbounded
#
# ======================================================================
# [TIMING] === Iter 1 phase breakdown (total 12.38s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.21s  (  1.7%)
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.3%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :      12.13s  ( 98.0%)  ################################################
#   TOTAL                          :      12.38s
#   #simplices=9, #scenarios=5, total_ms_pairs=45
#   fresh ms solves=0, cache hits=45
# ======================================================================
#
# [Iter 2] #simplices = 12, #active = 3, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 2] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T8            9.840882e-01      4.081767e+09     -2.959117e+10      4.920441e+00     [4.92e+00, 5.00e+10]    [-2.96e+10, 2.04e+10]     1
# T10           9.841057e-01      4.034003e+09     -2.982999e+10      4.920528e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T11           9.841365e-01      4.372534e+09     -2.813733e+10      4.920682e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
#
# == [Iter 2] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T9            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 2] created=12 (cum=35), active=3, active+UB=3, ms_recomputed=0
# [Iter 2] EF-ipopt: ok=True, ef_obj=0.9841670250482237, true_obj=9.841670e-01, time=0.100s
# [Iter 2] EF-UB improved by ipopt: 9.841670e-01 (per-scen), K=(-9.999828354228717, -99.99992195068927, 0.8142777250844004)
# [Iter 2] Pre-split gap: 3.943339e-04 (0.008%)
# [Iter 2] Active simplex ratio = 0.000648
# [Iter 2] UB point (-9.999828354228717, -99.99992195068927, 0.8142777250844004) is geometrically in simplices [8]
#   T8 verts=[9, 1, 4, 0]: λ=[0.151750, 0.427933, 0.000001, 0.420316], LB=4.920440896, c_s=[0.9961179007809912, 0.9451455440142829, 0.9562855646180515, 1.054552287644563, 0.9683395993974063]
#
# == [Iter 2] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.3109563158368893)
#              indep_Q(cs_K)=0.996118177
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902724169548, -99.99948714853234, 0.6339658487898319)
#              indep_Q(cs_K)=0.945145556
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.929724312898895, -99.99949924914802, 2.285226392626316)
#              indep_Q(cs_K)=0.956285567
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99901145451161, -99.99984484415484, 0.34762582010310356)
#              indep_Q(cs_K)=1.054552309
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025360974187, -99.99948615699039, 0.4418525403489427)
#              indep_Q(cs_K)=0.968339610
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999828354228717, -99.99992195068927, 0.8142777250844004) ==
#     scen 0: Q_s(K_EF)=0.996015234, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945126284, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.956484729, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054727425, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968481557, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.920835230, sum(c_s)=0.000000000, diff=4.920835e+00
#
# [Iter 2] LB = 4.920441 = UB(4.920835) + ms_b(-2.959e+10) from T8
# [Iter 2] Scene 0: Switched to c_s point. dist_ms_c=1.83e+01 < 1000.0, dist_c_verts=9.63e-01 > 1e-06
# [Iter 2] Scene 1: Switched to c_s point. dist_ms_c=1.81e+01 < 1000.0, dist_c_verts=2.86e-01 > 1e-06
# [Iter 2] Scene 2: Switched to c_s point. dist_ms_c=1.70e+01 < 1000.0, dist_c_verts=1.94e+00 > 1e-06
# [Iter 2] Scene 3: Switched to c_s point. dist_ms_c=1.94e+01 < 1000.0, dist_c_verts=3.59e-04 > 1e-06
# [Iter 2] Scene 4: Switched to c_s point. dist_ms_c=1.84e+01 < 1000.0, dist_c_verts=9.42e-02 > 1e-06
# Chosen node (-10.0, -100.0, 1.31095631583689) with ms=-5.978e+09 (simp T8, scene 0, rank #1, source=c_s)
# [Iter 2] LB simplex = T8, next node simplex = T8, scene 0
# [Selected Simp Info] Iter 2 | Simplex T8 Vertices:
#   v0: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   v1: (-10.0, -100.0, 100.0)
#   v2: (10.0, -100.0, -100.0)
#   v3: (-10.0, -100.0, -100.0)
#   -> New Point: (-10.0, -100.0, 1.31095631583689)
# [Iter 2] candidate rank #1: T8, scene=0, ms=-5.978e+09
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1     T8       0  -5.9782e+09     9.63e-01  (-10.0000, -100.0000, 1.3110)
#    2     T8       3  -5.9648e+09     3.59e-04    (-9.9990, -99.9998, 0.3476)
#    3     T8       2  -5.8947e+09     1.94e+00    (-9.9297, -99.9995, 2.2852)
#    4     T8       4  -5.8810e+09     9.42e-02    (-9.9990, -99.9995, 0.4419)
#    5     T8       1  -5.8725e+09     2.86e-01    (-9.9990, -99.9995, 0.6340)
#
# [Iter 2] per_tet=12, active after q_cut=3, tri_is_None=False
# [Iter 2] bad-quality active simplices (q < 0): 0
# [Iter 2] evaluating Q for scenario 0
# [Iter 2] evaluating Q for scenario 1
# [Iter 2] evaluating Q for scenario 2
# [Iter 2] evaluating Q for scenario 3
# [Iter 2] evaluating Q for scenario 4
#
# [Iter 2] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T8        0       c_s     5.0655e+09     -5.9782e+09    -9.1270e+08    9.9612e-01     (-10.0000, -100.0000, 1.3110)
#
# [Iter 2] subdivision type = edge (code=2) on simplex T8
#            edge local verts = (1, 0)
# [Iter 2] Elapsed: 0.254s
# [Invariant] MS scen None: dual=-5.765027e+09 > primal=-5.765027e+09
# [Invariant] MS scen None: dual=-5.747117e+09 > primal=-5.747117e+09
# [Invariant] MS scen None: dual=-5.710811e+09 > primal=-5.710811e+09
# ======================================================================
# [Iter 2] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 1, 4, 9)
#   Parent LB: 0.984088179 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167046, used=min=0.196833405 (per-scen)
#   Simplex volume: 3.428862e-01
#   Children (2):
#     T11 (0, 4, 9, 10): LB = 0.984008832
#     T12 (1, 4, 9, 10): LB = 0.984015762
#   New global LB: 0.984008832 (from T11 (0, 4, 9, 10))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984198851 (per-scen), point=(np.float64(-9.985357674016035), np.float64(-99.99966347976512), np.float64(1.0039253835410167))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999828354228717, -99.99992195068927, 0.8142777250844004)
#   UB source: EF_ipopt
#   UB simplex: (0, 1, 4, 9)
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.100s, ef_obj=0.9841670250482237, true_obj(per-scen)=0.984167046
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 2 phase breakdown (total 6.34s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.21s  (  3.4%)  #
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       6.09s  ( 96.0%)  ###############################################
#   TOTAL                          :       6.34s
#   #simplices=12, #scenarios=5, total_ms_pairs=60
#   fresh ms solves=0, cache hits=60
# ======================================================================
#
# [Iter 3] #simplices = 13, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 3] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.841057e-01      4.034003e+09     -2.982999e+10      4.920528e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T10           9.841365e-01      4.372534e+09     -2.813733e+10      4.920682e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T11           9.840088e-01      2.502349e+00     -1.127792e+00      4.920044e+00     [4.92e+00, 1.36e+01]     [3.79e+00, 1.25e+01]     0
# T12           9.840158e-01      4.247104e+09     -2.876448e+10      4.920079e+00     [4.92e+00, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
#
# == [Iter 3] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T8            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
#
# [Iter 3] created=13 (cum=50), active=4, active+UB=4, ms_recomputed=0
# [Iter 3] EF-ipopt: ok=True, ef_obj=0.9841670258648367, true_obj=9.841670e-01, time=0.109s
# [Iter 3] Pre-split gap: 7.910709e-04 (0.016%)
# [Iter 3] Active simplex ratio = 0.000648
# [Iter 3] UB point (-9.999024438505662, -99.99948567065238, 0.3476235438684009) is geometrically in simplices [8, 9, 10, 11, 12]
#   T8 verts=[8, 9, 4, 0]: λ=[0.000000, 1.000000, -0.000000, 0.000000], LB=4.921695500, c_s=[0.9962799749248459, 0.9452825839449608, 0.9572411321042049, 1.0545523593585613, 0.968339449454651]
#   T9 verts=[8, 1, 9, 0]: λ=[0.000000, 0.000000, 1.000000, -0.000000], LB=4.920528378, c_s=[0.9960764430968391, 0.9452367404106494, 0.9563232400081809, 1.0545523563538273, 0.9683395978579611]
#   T10 verts=[8, 1, 4, 9]: λ=[0.000000, 0.000000, 0.000000, 1.000000], LB=4.920682419, c_s=[0.9964245396380277, 0.9451261613958636, 0.9561437316349064, 1.0545523593806891, 0.9684356269584539]
#   T11 verts=[10, 0, 9, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=4.920044159, c_s=[0.9960031041694405, 0.9451257936125295, 0.9560257456984775, 1.0545518673636218, 0.9683376485628852]
#   T12 verts=[1, 10, 9, 4]: λ=[0.000000, -0.000000, 1.000000, -0.000000], LB=4.920078812, c_s=[0.9960108209976078, 0.9452377752093916, 0.9559401077826853, 1.0545523575630058, 0.9683377507185565]
#
# == [Iter 3] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T8 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.996279978
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.945282584
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#              indep_Q(cs_K)=0.957241133
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999020568929364, -99.99948286101699, 0.3462666779229522)
#              indep_Q(cs_K)=1.054552486
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024438505662, -99.99948567065238, 0.34762354386839434)
#              indep_Q(cs_K)=0.968339480
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T9 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999033139380614, -99.99949025787252, 1.236410021396523)
#              indep_Q(cs_K)=0.996076475
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902513272445, -99.999486036654, 0.4185371176428156)
#              indep_Q(cs_K)=0.945236742
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.47028712401834, -98.92297533538397, 2.28345416468709)
#              indep_Q(cs_K)=0.956323242
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999024093468384, -99.9994836182758, 0.3475998810479236)
#              indep_Q(cs_K)=1.054552378
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999025360137718, -99.99948615654938, 0.4417670961795307)
#              indep_Q(cs_K)=0.968339604
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T10 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.972014593399003, -99.99948636528407, 0.2120982447681723)
#              indep_Q(cs_K)=0.996424552
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999028558092824, -99.99948784255501, 0.768434177662689)
#              indep_Q(cs_K)=0.945126184
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-4.56657907155549, -99.99977399749714, 1.8816243937628139)
#              indep_Q(cs_K)=0.956143854
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999020457157568, -99.99948286651271, 0.34897061295835036)
#              indep_Q(cs_K)=1.054552383
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99902829208175, -99.99948770231035, 0.7412614817413219)
#              indep_Q(cs_K)=0.968435633
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T11 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.9135684148039656)
#              indep_Q(cs_K)=0.996003105
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.7849925655435896)
#              indep_Q(cs_K)=0.945125795
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.31095631583689)
#              indep_Q(cs_K)=0.956025749
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999990844652734, -99.99999702841606, 0.34763793944705945)
#              indep_Q(cs_K)=1.054551888
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 0.38840794338791684)
#              indep_Q(cs_K)=0.968337649
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#   --- T12 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99972409989392, -99.99985454169482, 1.0385146342826024)
#              indep_Q(cs_K)=0.996010827
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-7.9623154482805845, -99.9995946089729, 1.0854925896433145)
#              indep_Q(cs_K)=0.945237802
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.7405700145806413)
#              indep_Q(cs_K)=0.955940222
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999023134930745, -99.99948634964358, 0.34895057460920736)
#              indep_Q(cs_K)=1.054552382
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999069024548511, -99.99950917702328, 0.39165069797202556)
#              indep_Q(cs_K)=0.968337762
#   sum(c_s_dual)=0.000000000, UB_total=24.604176152, UB_per_scen=4.920835230
#
#   == Per-scenario Q_s at K_EF = (-9.999024438505662, -99.99948567065238, 0.3476235438684009) ==
#     scen 0: Q_s(K_EF)=0.996279978, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945282584, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957241133, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054552377, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968339480, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921695553, sum(c_s)=0.000000000, diff=4.921696e+00
#
# [Iter 3] LB = 4.920044 = UB(4.920835) + ms_b(-1.128e+00) from T11
# [Iter 3] Scene 0: Switched to c_s point. dist_ms_c=4.41e+01 < 1000.0, dist_c_verts=3.97e-01 > 1e-06
# [Iter 3] Scene 1: Switched to c_s point. dist_ms_c=4.39e+01 < 1000.0, dist_c_verts=4.37e-01 > 1e-06
# [Iter 3] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=4.58e+01 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 3] Scene 3: Switched to c_s point. dist_ms_c=4.14e+01 < 1000.0, dist_c_verts=1.09e-03 > 1e-06
# [Iter 3] Scene 4: Switched to c_s point. dist_ms_c=4.29e+01 < 1000.0, dist_c_verts=4.08e-02 > 1e-06
# Chosen node (-10.0, -100.0, 0.38840794338791684) with ms=-2.354e-01 (simp T11, scene 4, rank #1, source=c_s)
# [Iter 3] LB simplex = T11, next node simplex = T11, scene 4
# [Selected Simp Info] Iter 3 | Simplex T11 Vertices:
#   v0: (-10.0, -100.0, 1.31095631583689)
#   v1: (-10.0, -100.0, -100.0)
#   v2: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   v3: (10.0, -100.0, -100.0)
#   -> New Point: (-10.0, -100.0, 0.38840794338791684)
# [Iter 3] candidate rank #1: T11, scene=4, ms=-2.354e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T11       4  -2.3535e-01     4.08e-02  (-10.0000, -100.0000, 0.3884)
#    2    T11       1  -2.3305e-01     4.37e-01  (-10.0000, -100.0000, 0.7850)
#    3    T11       0  -2.3165e-01     3.97e-01  (-10.0000, -100.0000, 0.9136)
#    4    T11       2  -2.1876e-01     4.47e+01 (-1.1330, -100.0000, -43.6054)
#    5    T11       3  -2.0897e-01     1.09e-03  (-10.0000, -100.0000, 0.3476)
#
# [Iter 3] per_tet=13, active after q_cut=4, tri_is_None=False
# [Iter 3] bad-quality active simplices (q < 0): 0
# [Iter 3] evaluating Q for scenario 0
# [Iter 3] evaluating Q for scenario 1
# [Iter 3] evaluating Q for scenario 2
# [Iter 3] evaluating Q for scenario 3
# [Iter 3] evaluating Q for scenario 4
#
# [Iter 3] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T11       4       c_s     9.8036e-01     -2.3535e-01    7.4501e-01     9.6834e-01     (-10.0000, -100.0000, 0.3884)
#
# [Iter 3] subdivision type = edge (code=2) on simplex T11
#            edge local verts = (10, 0)
# [Iter 3] Elapsed: 0.603s
# ======================================================================
# [Iter 3] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (0, 4, 9, 10)
#   Parent LB: 0.984008832 (per-scen)
#   EF ef_obj(IPOPT): 0.196833405, true_obj(recalc): 0.984167047, used=min=0.196833405 (per-scen)
#   Simplex volume: 1.736907e-01
#   Children (2):
#     T12 (0, 4, 9, 11): LB = 0.984310297
#     T13 (4, 9, 10, 11): LB = 0.984008964
#   New global LB: 0.984008964 (from T13 (4, 9, 10, 11))
#   Location: INSIDE
#   Avg CS point Q-value: 0.984170419 (per-scen), point=(np.float64(-9.999998168930547), np.float64(-99.99999940568321), np.float64(0.7491126358038842))
#   Current UB: 0.984167046 (per-scen)
#   UB point: (-9.999024438505662, -99.99948567065238, 0.3476235438684009)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.109s, ef_obj=0.9841670258648367, true_obj(per-scen)=0.984167047
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 3 phase breakdown (total 6.27s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.56s  (  9.0%)  ####
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.04s  (  0.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       5.67s  ( 90.4%)  #############################################
#   TOTAL                          :       6.27s
#   #simplices=13, #scenarios=5, total_ms_pairs=65
#   fresh ms solves=0, cache hits=65
# ======================================================================
#
# [Iter 4] #simplices = 14, #active = 4, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 4] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.841057e-01      4.034003e+09     -2.982999e+10      4.920528e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T10           9.841365e-01      4.372534e+09     -2.813733e+10      4.920682e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# ...
# T19           9.840092e-01      2.502349e+00     -1.127792e+00      4.920046e+00     [4.92e+00, 1.36e+01]     [3.79e+00, 1.25e+01]     0
# T21           9.840093e-01      2.502349e+00     -1.127792e+00      4.920046e+00     [4.92e+00, 1.36e+01]     [3.79e+00, 1.25e+01]     0
#
# == [Iter 8] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T8            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
# T12           9.843103e-01      2.510372e+00     -1.087681e+00      4.921551e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T15           9.843087e-01      2.510358e+00     -1.087747e+00      4.921544e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
#
# [Iter 8] created=16 (cum=132), active=5, active+UB=1, ms_recomputed=0
# [Iter 8] EF-ipopt: ok=True, ef_obj=0.9841670871818087, true_obj=9.841671e-01, time=0.108s
# [Iter 8] Pre-split gap: 7.893773e-04 (0.016%)
# [Iter 8] Active simplex ratio = 0.000647
# [Iter 8] UB point (-9.999443501903894, -99.99999438488923, 0.3972941633360434) is geometrically in simplices [21]
#   T21 verts=[14, 4, 15, 10]: λ=[1.000000, -0.000000, -0.000000, 0.000000], LB=4.920046433, c_s=[0.9960032159667731, 0.9451257872900348, 0.9560257465269466, 1.0545538448497058, 0.9683378382902411]
#
# == [Iter 8] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T21 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999633199020536, -99.99986344333097, 0.9130770389132342)
#              indep_Q(cs_K)=0.996003218
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999518185287839, -99.9998206247642, 0.7883184276642032)
#              indep_Q(cs_K)=0.945125788
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.31095631583689)
#              indep_Q(cs_K)=0.956025749
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998180685038802, -99.99968494998755, 0.3880795595846953)
#              indep_Q(cs_K)=1.054553944
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99839907577514, -99.99968494654703, 0.38917585064035437)
#              indep_Q(cs_K)=0.968337839
#   sum(c_s_dual)=0.000000000, UB_total=24.604176132, UB_per_scen=4.920835226
#
#   == Per-scenario Q_s at K_EF = (-9.999443501903894, -99.99999438488923, 0.3972941633360434) ==
#     scen 0: Q_s(K_EF)=0.996235820, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945249649, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957146316, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054554034, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968337700, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921523518, sum(c_s)=0.000000000, diff=4.921524e+00
#
# [Iter 8] LB = 4.920046 = UB(4.920835) + ms_b(-1.128e+00) from T19
# [Iter 8] Scene 0: Switched to c_s point. dist_ms_c=4.41e+01 < 1000.0, dist_c_verts=3.82e-01 > 1e-06
# [Iter 8] Scene 1: Switched to c_s point. dist_ms_c=4.39e+01 < 1000.0, dist_c_verts=3.94e-01 > 1e-06
# [Iter 8] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=4.58e+01 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 8] Scene 3: Switched to c_s point. dist_ms_c=4.14e+01 < 1000.0, dist_c_verts=8.99e-05 > 1e-06
# [Iter 8] Scene 4: Switched to c_s point. dist_ms_c=4.29e+01 < 1000.0, dist_c_verts=2.46e-03 > 1e-06
# Chosen node (-9.999155934260353, -99.9996857620009, 0.3953746108537248) with ms=-2.354e-01 (simp T19, scene 4, rank #1, source=c_s)
# [Iter 8] LB simplex = T19, next node simplex = T19, scene 4
# [Selected Simp Info] Iter 8 | Simplex T19 Vertices:
#   v0: (-9.999153711959602, -99.99968493465855, 0.39296401910014866)
#   v1: (10.0, -100.0, -100.0)
#   v2: (-9.999068262495673, -99.9995087752586, 0.39089819750577715)
#   v3: (-10.0, -100.0, 1.31095631583689)
#   -> New Point: (-9.999155934260353, -99.9996857620009, 0.3953746108537248)
# [Iter 8] candidate rank #1: T19, scene=4, ms=-2.354e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T19       4  -2.3535e-01     1.91e-03    (-9.9992, -99.9997, 0.3954)
#    2    T19       1  -2.3305e-01     3.89e-01    (-9.9995, -99.9997, 0.7865)
#    3    T19       0  -2.3165e-01     3.82e-01    (-9.9996, -99.9998, 0.9288)
#    4    T19       2  -2.1876e-01     4.47e+01 (-1.1330, -100.0000, -43.6054)
#    5    T19       3  -2.0897e-01     8.99e-05    (-9.9990, -99.9995, 0.3908)
#
# [Iter 8] per_tet=16, active after q_cut=5, tri_is_None=False
# [Iter 8] bad-quality active simplices (q < 0): 0
# [Iter 8] evaluating Q for scenario 0
# [Iter 8] evaluating Q for scenario 1
# [Iter 8] evaluating Q for scenario 2
# [Iter 8] evaluating Q for scenario 3
# [Iter 8] evaluating Q for scenario 4
#
# [Iter 8] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T19       4       c_s     9.6834e-01     -2.3535e-01    7.3299e-01     9.6834e-01     (-9.9992, -99.9997, 0.3954)
#
# [Iter 8] subdivision type = edge (code=2) on simplex T19
#            edge local verts = (15, 10)
# [Iter 8] Elapsed: 0.306s
# ======================================================================
# [Iter 8] LB SPLIT DIAGNOSTIC
#   Selected (parent) simplex: (4, 10, 13, 15)
#   Parent LB: 0.984009170 (per-scen)
#   EF ef_obj(IPOPT): 0.196833417, true_obj(recalc): 0.984167108, used=min=0.196833417 (per-scen)
#   Simplex volume: 5.348110e-04
#   Children (2):
#     T21 (4, 10, 13, 16): LB = 0.984009747
#   New global LB: 0.984009287 (from T20 (4, 10, 14, 15))
#   Location: OUTSIDE
#   Avg CS point Q-value: 0.984169283 (per-scen), point=(np.float64(-9.999455241421224), np.float64(-99.9997438691054), np.float64(0.7624888489173827))
#   Current UB: 0.984167045 (per-scen)
#   UB point: (-9.999443501903894, -99.99999438488923, 0.3972941633360434)
#   UB source: unknown
#   UB simplex: None
#   EF-IPOPT: ok=True, status=ok, term=optimal, time=0.108s, ef_obj=0.9841670871818087, true_obj(per-scen)=0.984167108
# ======================================================================
#
# ======================================================================
# [TIMING] === Iter 8 phase breakdown (total 3.28s) ===
#   1_vertex_UB                    :       0.00s  (  0.0%)
#   2_evaluate_all_tetra           :       0.00s  (  0.0%)
#   3_active_filter_print          :       0.00s  (  0.0%)
#   4_LB_selection                 :       0.00s  (  0.0%)
#   5_EF_UB_solve                  :       0.25s  (  7.6%)  ###
#   6_candidate_selection          :       0.00s  (  0.0%)
#   7_Q_eval_new_node              :       0.05s  (  1.6%)
#   8_mesh_subdivide               :       0.00s  (  0.0%)
#   9_end_of_iter_reeval           :       2.98s  ( 90.7%)  #############################################
#   TOTAL                          :       3.28s
#   #simplices=16, #scenarios=5, total_ms_pairs=80
#   fresh ms solves=0, cache hits=80
# ======================================================================
#
# [Iter 9] #simplices = 16, #active = 5, bad-quality cut = 0, bad-shape cut = 0
# == [Iter 9] ACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T9            9.841057e-01      4.034003e+09     -2.982999e+10      4.920528e+00     [4.92e+00, 5.00e+10]    [-2.98e+10, 2.02e+10]     1
# T10           9.841365e-01      4.372534e+09     -2.813733e+10      4.920682e+00     [4.92e+00, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T11           9.840158e-01      4.247104e+09     -2.876448e+10      4.920079e+00     [4.92e+00, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T20           9.840093e-01      2.502349e+00     -1.127792e+00      4.920046e+00     [4.92e+00, 1.36e+01]     [3.79e+00, 1.25e+01]     0
# T21           9.840097e-01      2.502349e+00     -1.127792e+00      4.920049e+00     [4.92e+00, 1.36e+01]     [3.79e+00, 1.25e+01]     0
#
# == [Iter 9] INACTIVE simplices: LB / UB / sum(ms_s) / sum(c_s) (per-scenario) ==
# simp                    LB                UB            sum_ms           sum_c_s                Range(As)             Range(As+ms) #InfV
# ----------------------------------------------------------------------------------------------------------------------------------------
# T0            1.023823e+00      4.725871e+09     -2.637064e+10      5.119117e+00     [1.12e+01, 5.00e+10]    [-2.64e+10, 2.36e+10]     1
# T1            1.026329e+00      4.382643e+09     -2.808678e+10      5.131646e+00     [1.11e+01, 5.00e+10]    [-2.81e+10, 2.19e+10]     1
# T2            1.001069e+00      4.242039e+09     -2.878981e+10      5.005344e+00     [1.11e+01, 5.00e+10]    [-2.88e+10, 2.12e+10]     1
# T3            1.023670e+00      4.317792e+09     -2.841104e+10      5.118349e+00     [1.36e+01, 5.00e+10]    [-2.84e+10, 2.16e+10]     2
# T4            1.043636e+00               inf               inf      5.218179e+00     [1.36e+01, 5.00e+10]               [inf, inf]     2
# T5            9.939709e-01      1.385630e+00     -6.711390e+00      4.969854e+00     [4.92e+00, 1.36e+01]    [-1.79e+00, 6.93e+00]     0
# T6            9.899977e-01      4.017689e+09     -2.991155e+10      4.949989e+00     [4.92e+00, 5.00e+10]    [-2.99e+10, 2.01e+10]     1
# T7            9.883553e-01      4.278531e+09     -2.860734e+10      4.941777e+00     [4.92e+00, 5.00e+10]    [-2.86e+10, 2.14e+10]     1
# T8            9.843391e-01      2.510715e+00     -1.085964e+00      4.921695e+00     [4.92e+00, 1.36e+01]     [3.84e+00, 1.26e+01]     0
# T12           9.843103e-01      2.510372e+00     -1.087681e+00      4.921551e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
# T15           9.843087e-01      2.510358e+00     -1.087747e+00      4.921544e+00     [4.92e+00, 1.36e+01]     [3.83e+00, 1.26e+01]     0
#
# [Iter 9] created=16 (cum=149), active=5, active+UB=1, ms_recomputed=0
# [Iter 9] EF-ipopt: ok=True, ef_obj=0.984167060928239, true_obj=9.841671e-01, time=0.107s
# [Iter 9] Pre-split gap: 7.887936e-04 (0.016%)
# [Iter 9] Active simplex ratio = 0.000647
# [Iter 9] UB point (-9.999443501903894, -99.99999438488923, 0.3972941633360434) is geometrically in simplices [20]
#   T20 verts=[14, 4, 15, 10]: λ=[1.000000, -0.000000, -0.000000, 0.000000], LB=4.920046433, c_s=[0.9960032159667731, 0.9451257872900348, 0.9560257465269466, 1.0545538448497058, 0.9683378382902411]
#
# == [Iter 9] CS DUAL vs PRIMAL diagnostic (simplices containing UB point) ==
#   --- T20 ---
#     scen 0: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999633199020536, -99.99986344333097, 0.9130770389132342)
#              indep_Q(cs_K)=0.996003218
#     scen 1: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.999518185287839, -99.9998206247642, 0.7883184276642032)
#              indep_Q(cs_K)=0.945125788
#     scen 2: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-10.0, -100.0, 1.31095631583689)
#              indep_Q(cs_K)=0.956025749
#     scen 3: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.998180685038802, -99.99968494998755, 0.3880795595846953)
#              indep_Q(cs_K)=1.054553944
#     scen 4: status=?, dual=N/A, primal=N/A
#              cs_primal_K=(-9.99839907577514, -99.99968494654703, 0.38917585064035437)
#              indep_Q(cs_K)=0.968337839
#   sum(c_s_dual)=0.000000000, UB_total=24.604176132, UB_per_scen=4.920835226
#
#   == Per-scenario Q_s at K_EF = (-9.999443501903894, -99.99999438488923, 0.3972941633360434) ==
#     scen 0: Q_s(K_EF)=0.996235820, c_s_dual=N/A
#     scen 1: Q_s(K_EF)=0.945249649, c_s_dual=N/A
#     scen 2: Q_s(K_EF)=0.957146316, c_s_dual=N/A
#     scen 3: Q_s(K_EF)=1.054554034, c_s_dual=N/A
#     scen 4: Q_s(K_EF)=0.968337700, c_s_dual=N/A
#     SUM Q_s(K_EF)=4.921523518, sum(c_s)=0.000000000, diff=4.921524e+00
#
# [Iter 9] LB = 4.920046 = UB(4.920835) + ms_b(-1.128e+00) from T20
# [Iter 9] Scene 0: Switched to c_s point. dist_ms_c=4.41e+01 < 1000.0, dist_c_verts=3.98e-01 > 1e-06
# [Iter 9] Scene 1: Switched to c_s point. dist_ms_c=4.39e+01 < 1000.0, dist_c_verts=3.91e-01 > 1e-06
# [Iter 9] Scene 2: Kept ms point (c_s too close to verts). dist_ms_c=4.58e+01 < 1000.0 BUT dist_c_verts=0.00e+00 <= 1e-06
# [Iter 9] Scene 3: Switched to c_s point. dist_ms_c=4.14e+01 < 1000.0, dist_c_verts=4.98e-03 > 1e-06
# [Iter 9] Scene 4: Switched to c_s point. dist_ms_c=4.29e+01 < 1000.0, dist_c_verts=3.86e-03 > 1e-06
# Chosen node (-9.99839907577514, -99.99968494654703, 0.3891758506403545) with ms=-2.354e-01 (simp T20, scene 4, rank #1, source=c_s)
# [Iter 9] LB simplex = T20, next node simplex = T20, scene 4
# [Selected Simp Info] Iter 9 | Simplex T20 Vertices:
#   v0: (-9.999443501903894, -99.99999438488923, 0.3972941633360434)
#   v1: (10.0, -100.0, -100.0)
#   v2: (-9.999153711959602, -99.99968493465855, 0.39296401910014866)
#   v3: (-10.0, -100.0, 1.31095631583689)
#   -> New Point: (-9.99839907577514, -99.99968494654703, 0.3891758506403545)
# [Iter 9] candidate rank #1: T20, scene=4, ms=-2.354e-01
# == ms candidates (sorted by (ms, -dist)) ==
# rank   simp   scene           ms    mind(all)                             pt
# ----------------------------------------------------------------------------
#    1    T20       4  -2.3535e-01     1.62e-03    (-9.9984, -99.9997, 0.3892)
#    2    T20       1  -2.3305e-01     3.91e-01    (-9.9995, -99.9998, 0.7883)
#    3    T20       0  -2.3165e-01     3.98e-01    (-9.9996, -99.9999, 0.9131)
#    4    T20       2  -2.1876e-01     4.47e+01 (-1.1330, -100.0000, -43.6054)
#    5    T20       3  -2.0897e-01     1.88e-03    (-9.9982, -99.9997, 0.3881)
#
# [Iter 9] per_tet=16, active after q_cut=5, tri_is_None=False
# [Iter 9] bad-quality active simplices (q < 0): 0
# [Iter 9] evaluating Q for scenario 0
# [Iter 9] evaluating Q for scenario 1
# [Iter 9] evaluating Q for scenario 2
# [Iter 9] evaluating Q for scenario 3
# [Iter 9] evaluating Q for scenario 4
#
# [Iter 9] Next Point Details:
# Simplex   Scene   Type    As             ms             As+ms          Q              (Kp, Ki, Kd)
# --------------------------------------------------------------------------------------------------------------------
# T20       4       c_s     9.6840e-01     -2.3535e-01    7.3305e-01     9.6834e-01     (-9.9984, -99.9997, 0.3892)
#
# [Iter 9] subdivision type = edge (code=2) on simplex T20
#            edge local verts = (4, 15)
# [Iter 9] Elapsed: 0.277s
